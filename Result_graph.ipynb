c3m = [27.7382683761336, 26.077251081447024, 27.469421664657528, 27.88938738679669, 34.375086396951495,50.03224421676261, 40.15974608168018, 45.879448366843086, 45.23791036205942, 40.85254502136027,124.39188688946446, 63.17891069322882, 50.75789865920778, 68.79926044366141, 43.99170546668934]
c4m = [28.589194610003233, 26.09450590893286, 27.07929043660282, 28.4380860935207, 29.971295464182443,50.476870574104375, 39.184174936173356, 50.314968312994374, 43.569815843673375, 39.7324585846693,144.41733104790444, 84.70088353676805, 46.04348964083102, 51.12402376647519, 43.810772199261315]

# %%
s1m = [35.72193647636886, 28.690231190635394, 27.223971359614385, 26.255899388632805, 26.195623837600344,81.28406984090188, 59.44142637632719, 61.82929545287458, 81.068729513338, 64.85466968400625,223.47081018313494, 80.76305636588098, 70.25481159426869, 55.35517893990295, 96.75286310165868]
s2m = [29.113005921238322, 26.699535198380584, 26.293170399796956, 27.399934059240408, 28.537244048445082,49.922786943894984, 52.145549267728995, 71.06329320025411, 44.43072139357994, 44.63024133884122,106.2644727577627, 61.387580847175194, 53.38394112416419, 47.91822394065961, 53.65347362167874]
s3m = [25.60551238665869, 28.122097237109635, 26.535792020739184, 28.500721114142053, 28.528114718754264,43.218534654148186, 39.20510092726554, 40.14752428171062, 42.20120607549088, 40.13947890448981,124.23567004521695, 70.02055915569456, 52.728833672499064, 56.21276628596741, 57.190819668105135]
s4m = [28.50709987664792, 25.9594157879144, 26.449950784753412, 27.427447584527762, 28.91327199110933,57.54518593263981, 44.01100777824726, 46.67364583149601, 42.47947639391648, 43.12174838302616,89.81239969220938, 56.21876880281408, 50.283602355582026, 46.05960239626535, 47.55752751068812]

# %%
print(statistics.stdev(c1[0:5]),statistics.stdev(c2[0:5]),statistics.stdev(c3[0:5]),statistics.stdev(c4[0:5]))
# Out:
# 1.923723642700125 0.7482899343449297 0.6849775186907364 0.7276487133469303

# %%
print(statistics.stdev(s1[0:5]),statistics.stdev(s2[0:5]),statistics.stdev(s3[0:5]),statistics.stdev(s4[0:5]))
# Out:
# 3.754021058164655 0.2180569989049749 0.8868051847011932 1.3679908206180529

# %%
print(statistics.stdev(c1m[0:5]),statistics.stdev(c2m[0:5]),statistics.stdev(c3m[0:5]),statistics.stdev(c4m[0:5]))
# Out:
# 2.4076502229884347 0.9071142068354587 3.2473555664760223 1.4914545664767915

# %%
print(statistics.stdev(s1m[0:5]),statistics.stdev(s2m[0:5]),statistics.stdev(s3m[0:5]),statistics.stdev(s4m[0:5]))
# Out:
# 3.9894487787045936 1.1964439250963388 1.318674987140794 1.27289660607814

# %%
lower = 10
upper = 15

# %%
data = c1[lower:upper] + c2[lower:upper] + c3[lower:upper] + c4[lower:upper] + s1[lower:upper] + s2[lower:upper] + s3[lower:upper] + s4[lower:upper]
model = ['11L-Model, Case 1'] * 5 + ['11L-Model, Case 2'] * 5 + ['11L-Model, Case 3'] * 5 + ['11L-Model, Case 4'] * 5 + ['8L-Model, Case 1'] * 5 + ['8L-Model, Case 2'] * 5 + ['8L-Model, Case 3'] * 5 + ['8L-Model, Case 4'] * 5
folds = ['1','2','3','4','5'] * 8

# %%
df = pd.DataFrame(columns = ['Data','Model','Folds'])
df['Data'] = data
df['Model'] = model
df['Folds'] = folds

# %%
plt.figure(figsize=(15,15))
sns.barplot(x = 'Folds', y = 'Data', hue = 'Model', data = df)
plt.xlabel('Folds',fontsize=25, ha='center')
plt.ylabel('RMSE',fontsize=25, ha='center')
plt.tick_params(labelsize=25)
plt.title('RMSE Score For 11L-Model & 8L-Model Each Fold 1 Hour Period',fontsize=30, ha='center')
plt.legend(fontsize=20, loc = 1)
plt.tight_layout()
plt.savefig('C:/Users/Anton/Desktop/Exjobb MSC/graph_ex/cases_rmse_folds_1.PNG')

# %%
data = c1m[lower:upper] + c2m[lower:upper] + c3m[lower:upper] + c4m[lower:upper] + s1m[lower:upper] + s2m[lower:upper] + s3m[lower:upper] + s4m[lower:upper]
model = ['11L-Model, Case 1'] * 5 + ['11L-Model, Case 2'] * 5 + ['11L-Model, Case 3'] * 5 + ['11L-Model, Case 4'] * 5 + ['8L-Model, Case 1'] * 5 + ['8L-Model, Case 2'] * 5 + ['8L-Model, Case 3'] * 5 + ['8L-Model, Case 4'] * 5
folds = ['1','2','3','4','5'] * 8

# %%
dfm = pd.DataFrame(columns = ['Data','Model','Folds'])
dfm['Data'] = data
dfm['Model'] = model
dfm['Folds'] = folds

# %%
plt.figure(figsize=(15,15))
sns.barplot(x = 'Folds', y = 'Data', hue = 'Model', data = dfm)
plt.xlabel('Folds',fontsize=25, ha='center')
plt.ylabel('MAE',fontsize=25, ha='center')
plt.tick_params(labelsize=25)
plt.title('MAE Score For 11L-Model & 8L-Model Each Fold 2 Hour Period',fontsize=30, ha='center')
plt.legend(fontsize=20, loc = 1)
plt.tight_layout()
plt.savefig('C:/Users/Anton/Desktop/Exjobb MSC/graph_ex/cases_mae_folds_2.PNG')

# %%
data = c4[0:15] + s4[0:15]
period = (['10 Min'] * 5 + ['1 Hour'] * 5 + ['2 Hour'] * 5)*2
model = ['11L-Model'] * 15 + ['8L-Model'] * 15

# %%
dfc = pd.DataFrame(columns = ['Data','Model','Period'])
dfc['Data'] = data
dfc['Model'] = model
dfc['Period'] = period

# %%
plt.figure(figsize=(15,15))
sns.barplot(x = 'Period', y = 'Data', hue = 'Model', data = dfc)
plt.xlabel('Period',fontsize=25, ha='center')
plt.ylabel('RMSE',fontsize=25, ha='center')
plt.tick_params(labelsize=25)
plt.title('RMSE Score For 11L-Model & 8L-Model Each Period Case 4',fontsize=30, ha='center')
plt.legend(fontsize=20, loc = 2)
plt.tight_layout()
plt.savefig('C:/Users/Anton/Desktop/Exjobb MSC/graph_ex/c4_rmse.PNG')

# %%
data = c4m[0:15] + s4m[0:15]
period = (['10 Min'] * 5 + ['1 Hour'] * 5 + ['2 Hour'] * 5)*2
model = ['11L-Model'] * 15 + ['8L-Model'] * 15

# %%
dfcm = pd.DataFrame(columns = ['Data','Model','Period'])
dfcm['Data'] = data
dfcm['Model'] = model
dfcm['Period'] = period

# %%
plt.figure(figsize=(15,15))
sns.barplot(x = 'Period', y = 'Data', hue = 'Model', data = dfcm)
plt.xlabel('Period',fontsize=25, ha='center')
plt.ylabel('MAE',fontsize=25, ha='center')
plt.tick_params(labelsize=25)
plt.title('MAE Score For 11L-Model & 8L-Model Each Period Case 4',fontsize=30, ha='center')
plt.legend(fontsize=20, loc = 2)
plt.tight_layout()
plt.savefig('C:/Users/Anton/Desktop/Exjobb MSC/graph_ex/c4_mae.PNG')

# %%
data = c1[lower:upper] + c2[lower:upper] + c3[lower:upper] + c4[lower:upper] + s1[lower:upper] + s2[lower:upper] + s3[lower:upper] + s4[lower:upper]
model = ['11L-Model, Case 1'] * upper + ['11L-Model, Case 2'] * upper + ['11L-Model, Case 3'] * upper + ['11L-Model, Case 4'] * upper + ['8L-Model, Case 1'] * upper + ['8L-Model, Case 2'] * upper + ['8L-Model, Case 3'] * upper + ['8L-Model, Case 4'] * upper
period = (['10 Min'] * 5 + ['1 Hour'] * 5 + ['2 Hour'] * 5)*4*2

# %%
df_all = pd.DataFrame(columns = ['Data','Model','Period'])
df_all['Data'] = data
df_all['Model'] = model
df_all['Period'] = period

# %%
plt.figure(figsize=(15,15))
sns.barplot(x = 'Period', y = 'Data', hue = 'Model', data = df_all)
plt.xlabel('Period',fontsize=25, ha='center')
plt.ylabel('RMSE',fontsize=25, ha='center')
plt.tick_params(labelsize=25)
plt.title('RMSE Score For 11L-Model & 8L-Model Each Period Each Case',fontsize=30, ha='center')
plt.legend(fontsize=20, loc = 2)
plt.tight_layout()
plt.savefig('C:/Users/Anton/Desktop/Exjobb MSC/graph_ex/cases_rmse.PNG')

# %%
data = c1m[lower:upper] + c2m[lower:upper] + c3m[lower:upper] + c4m[lower:upper] + s1m[lower:upper] + s2m[lower:upper] + s3m[lower:upper] + s4m[lower:upper]
model = ['11L-Model, Case 1'] * upper + ['11L-Model, Case 2'] * upper + ['11L-Model, Case 3'] * upper + ['11L-Model, Case 4'] * upper + ['8L-Model, Case 1'] * upper + ['8L-Model, Case 2'] * upper + ['8L-Model, Case 3'] * upper + ['8L-Model, Case 4'] * upper
period = (['10 Min'] * 5 + ['1 Hour'] * 5 + ['2 Hour'] * 5)*4*2

# %%
df_all2 = pd.DataFrame(columns = ['Data','Model','Period'])
df_all2['Data'] = data
df_all2['Model'] = model
df_all2['Period'] = period

# %%
plt.figure(figsize=(15,15))
sns.barplot(x = 'Period', y = 'Data', hue = 'Model', data = df_all2)
plt.xlabel('Period',fontsize=25, ha='center')
plt.ylabel('MAE',fontsize=25, ha='center')
plt.tick_params(labelsize=25)
plt.title('MAE Score For 11L-Model & 8L-Model Each Period Each Case',fontsize=30, ha='center')
plt.legend(fontsize=20, loc = 2)
plt.tight_layout()
plt.savefig('C:/Users/Anton/Desktop/Exjobb MSC/graph_ex/cases_mae.PNG')
